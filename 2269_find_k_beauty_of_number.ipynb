# %%
# num=240
# k=2
# num1=str(num)
# divisor=0
# for i in range(len(num1)-k+1):
#     for j in range(i,i+k):
#         x=num1[j]+num1[j+1]
#         x=int(x)
        
#         if(x==0): continue
#         elif(num%x==0):
#             divisor+=1
#         break

# print(divisor)
# Out:
# 2

# %%
num=430043
k=2
num1=str(num)
count=0
for i in range(len(num1)-k+1):
    part=int(num1[i:i+k])

    if part!=0 and num%part==0:
        count+=1

print(count)
# Out:
# 2
